# %% [markdown]
# ## Randić vs radius na malih grafih

# %% [markdown]
# Veljati mora $ Ra(G) \geq rad(G) -1$

# %% [markdown]
# ### Randićev indeks

# %%
def randic(graf):
    '''vrne randicev indeks za nek graf'''
    vsota = 0
    povezave = graf.edges()
    stopnje = graf.degree()
    for edge in povezave:
        u, v,_ = edge
        d_u = stopnje[u]
        d_v = stopnje[v]
        vsota += 1/((d_u * d_v)**(1/2))
    return(vsota)

# %% [markdown]
# ###### Za izračun radiusa grafa je že vgrajena funkcija

# %% [markdown]
# Primer na polnem grafu s 5 vozlišči

# %%
G = graphs.CompleteGraph(5)

# %%
G

# %%
randic(G) >= G.radius() - 1
# Out:
# True

# %% [markdown]
# Primer za

# %%
H = graphs.HouseGraph()

# %%
H

# %%
bool(randic(H) >= H.radius() - 1)
# Out:
# True

# %% [markdown]
# #### Funkcija, ki bo za vse grafe velikosti $n$ preverila, če neenakost velja.

# %%
def preveri_za_vse(n):
    '''Preveri, če neenakost velja na vseh enostavnih povezanih grafih z n vozlišči in manj.'''
    for i in range(2, n):
        grafi = list(graphs.nauty_geng(str(i)+" -c"))
        for graf in grafi:
            if randic(graf) < graf.radius() - 1:
                return False
    return True

# %%
preveri_za_vse(5)
# Out:
# True

# %%
preveri_za_vse(8)
# Out:
# True

# %%
preveri_za_vse(9)
# Out:
# True
